# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MrNICEForBonusWinner/flyrank-ml-internship-starter/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# One row represents one page-query record from the Search Console data for a single date.
#
# For this assignment, I will use data from March 2026 (month = 2026-03). This gives me a complete month to explore without using the final outcome month.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# Feature:
# Clicks, impressions, CTR, and average position. These can be used to describe page performance before making a prediction.
#
# Label:
# Whether the page performs well based on the target defined for this task.
#
# Context:
# Page URL, search query, and date. These help identify each record but are not direct prediction features.
#
# Excluded:
# Any future information or outcome-based values are excluded because they would cause data leakage and make the model unrealistic.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
query = """
SELECT
COUNT(*) AS row_count,
MIN(report_date) AS earliest_date,
MAX(report_date) AS latest_date
FROM 'hf://datasets/FlyRank/internship-warehouse/fact_content_daily_performance/month=2026-03/data_0.parquet'
"""

df_result = con.sql(query).df()
display(df_result)
# Out:
#    row_count earliest_date latest_date
# 0    9841378    2026-03-01  2026-03-31

# %% [markdown]
# This dataset only shows what is available in the warehouse, so it cannot explain why user behavior changed. It may also contain uneven historical coverage across pages and time periods. Because the data comes from specific sources, it should be used to support decisions rather than draw complete conclusions.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [yes] Every section above is filled — markdown thinking AND the code that backs it
# - [yes] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [yes] No client names, URLs, or private queries anywhere
# - [yes] My claims use careful words: observed, measured, directional, decision-support
# - [yes] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
